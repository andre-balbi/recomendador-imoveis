# %% [markdown]
# O mercado imobiliário brasileiro tem passado por um momento de aumento de preços nos últimos anos, puxados pelo aumento da taxa básica de juros (Selic) e pelo custo do material da construção civil, e esse fenômeno não ocorre apenas no Brasil, os preços dos imóveis dispararam pelo mundo. Além dos motivos supramencionados, outro fator que tem forte impacto nesse.

# %% [markdown]
# Enquanto os donos dos imóveis tem muitas razões para comemorar, o mesmo não ocorre com quem está em busca de um apartamento para comprar ou alugar.

# %% [markdown]
# Além dos motivos supramencionados, destacam-se outros fatores, tais como:
# "Os preços das moradias estão subindo por causa da pandemia, não apesar dela", diz Kate Everett-Allen, chefe de Pesquisa Residencial Internacional da Knight Frank, à BBC News Mundo, o serviço de notícias em espanhol da BBC. Com as profundas mudanças geradas a partir de 2020, explica ela, se gerou uma reavaliação maciça das necessidades de moradia das pessoas. "Esta é uma corrida por espaço. As pessoas estão comprando como loucas."
# Referência:
# https://economia.uol.com.br/noticias/bbc/2021/08/02/precos-dos-imoveis-disparam-pelo-mundo.htm

# %% [markdown]
# Ultimamente, o mercado de alugueis anda tão imprevisível quanto o próprio mercado de compra e venda dos mesmos. Diante disso, há a necessidade de uma pesquisa apurada em todo o montante de ofertas disponíveis para alugar com o objetivo de responder as seguintes perguntas:
# - Como é o comportamento da distribuição dos preços dos imóveis disponíveis pra alugar?
# - Quais as regiões mais valorizadas da cidade?
# - Qual a área mais interessante pra iniciar a procura?

# %% [markdown]
# No segundo momento:
# - Criar um modelo de recomendação baseado nas minhas preferencias.
# - Criar um modelo preditivo capaz de avaliar se o apartamento (ou apartamentos) sugerido está acima ou abaixo do preço praticado no mercado. <-- Não foi aplicado

# %%
import glob
import json
import os
import re
import time
import warnings
from datetime import datetime

import bs4
import numpy as np
import pandas as pd
import pycep_correios as pycep
import requests as rq
import tqdm
from unidecode import unidecode

warnings.filterwarnings("ignore")

# %config Completer.use_jedi = False

# %% [markdown]
# # Filtro utilizado para o webscapping

# %% [markdown]
# ## Opção #01

# %%
query = 'filtro_centro_sp'

query = re.sub(' +', ' ', query)
query = unidecode(query.strip().lower()).replace(' ', '%20') # Trasnformacao para o formado de busca no olx
query
# Out:
# 'filtro_centro_sp'

# %%
# URL para utilizar a query (busca)
#url = 'https://sp.olx.com.br/imoveis/aluguel/apartamentos?o={page}&q={query}'

# %% [markdown]
# ## Opção #02

# %%
# URL para utilizar filtro (Centro de Sao Paulo)
url = 'https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o={page}'

# %%
# User- agent for get response
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}

response = rq.get(url, headers= headers)
response # 200 - ok!
# Out:
# <Response [200]>

# %% [markdown]
# # Salvando as paginas em HTML das abas da pesquisa (01_raw_data_olx)

# %%
pages = 50 # Quantidade de paginas baixadas
source = 'olx' # Fonte dos dados

# %%
try:
    now = datetime.now().strftime('%Y-%m-%d') # Data de hoje
    os.mkdir(f'./01_raw_data_olx/{now}')
except:
    pass

# %%
# Salvando as X paginas para scrapping offline
try:
    now = datetime.now().strftime('%Y-%m-%d') # Data de hoje
    os.mkdir(f'./01_raw_data_olx/{now}') # Criando uma pasta com a data de hoje
except:
    pass

for page in tqdm.tqdm_notebook(range(1,pages+1)):
    
    #url_ = url.format(query=query, page=page) # <-- url_ utilizando query
    url_ = url.format(page=page)
    print(f'Aba {page}:\n{url_}')
    
    response = rq.get(url_, headers= headers)
    
    with open("./01_raw_data_olx/{}/{}_aba_{}.html".format(now, query, page), 'w+', encoding='utf-8') as output:
        output.write(response.text)
    time.sleep(2)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Aba 1:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=1
# Aba 2:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=2
# Aba 3:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=3
# Aba 4:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=4
# Aba 5:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=5
# Aba 6:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=6
# Aba 7:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=7
# Aba 8:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=8
# Aba 9:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=9
# Aba 10:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=10
# Aba 11:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=11
# Aba 12:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=12
# Aba 13:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=13
# Aba 14:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=14
# Aba 15:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=15
# Aba 16:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=16
# Aba 17:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=17
# Aba 18:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=18
# Aba 19:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=19
# Aba 20:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=20
# Aba 21:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=21
# Aba 22:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=22
# Aba 23:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=23
# Aba 24:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=24
# Aba 25:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=25
# Aba 26:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=26
# Aba 27:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=27
# Aba 28:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=28
# Aba 29:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=29
# Aba 30:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=30
# Aba 31:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=31
# Aba 32:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=32
# Aba 33:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=33
# Aba 34:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=34
# Aba 35:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=35
# Aba 36:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=36
# Aba 37:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=37
# Aba 38:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=38
# Aba 39:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=39
# Aba 40:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=40
# Aba 41:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=41
# Aba 42:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=42
# Aba 43:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=43
# Aba 44:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=44
# Aba 45:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=45
# Aba 46:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=46
# Aba 47:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=47
# Aba 48:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=48
# Aba 49:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=49
# Aba 50:
# https://sp.olx.com.br/sao-paulo-e-regiao/centro/imoveis/aluguel/apartamentos?o=50

# %% [markdown]
# # Coletando os links de cada pagina salva (01_raw_data_olx)

# %%
# Scrapping nas paginas salvas
for page in tqdm.tqdm_notebook(range(1,pages+1)):
    with open('./01_raw_data_olx/{}/{}_aba_{}.html'.format(now, query, page), 'r+', encoding='utf-8') as html:
        
        now = datetime.now().strftime('%Y-%m-%d') # Data de hoje
        
        page_html = html.read()
        
        parsed = bs4.BeautifulSoup(page_html)
        
        tags = parsed.findAll("a")
        
        for tag in tags:
            if tag.has_attr('data-lurker_list_id'):
                link = tag['href']
                title = tag['title']
                cod = tag['data-lurker_list_id']

                
                with open(f"./01_parsed_links/parsed_links_{now}.json", "a+") as output:
                    data = {"link":link, # link
                           "title":title, # Titulo do anuncio
                           "query":query, # Query utilizada para busca
                           'list_id':cod, # Codigo do anuncio (unico)
                           'aqs_date':now, # Data de aquisicao dos dados
                           'source':source}
                           #'thumb': thumb} # Fonte dos dados (olx)
                    output.write("{}\n".format(json.dumps(data)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ## Verificação do resultado e processando os dados

# %%
df_1 = pd.read_json(f'./01_parsed_links/parsed_links_{now}.json', lines=True)
df_1.tail()
# Out:
#                                                    link  \
# 2495  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 2496  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 2497  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 2498  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 2499  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
#
#                                                   title             query  \
# 2495  Ótimo apartamento de 42 m² com sacada para loc...  filtro_centro_sp
# 2496                         Studio de 23 m² com sacada  filtro_centro_sp
# 2497                         Studio de 22 m² com sacada  filtro_centro_sp
# 2498                         Studio de 23 m² com sacada  filtro_centro_sp
# 2499                         Studio de 22 m² com sacada  filtro_centro_sp
#
#         list_id    aqs_date source
# 2495  950600339  2021-11-10    olx
# 2496  950600342  2021-11-10    olx
# 2497  950600351  2021-11-10    olx
# 2498  950600359  2021-11-10    olx
# 2499  950600365  2021-11-10    olx

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   link      2500 non-null   object
#  1   title     2500 non-null   object
#  2   query     2500 non-null   object
#  3   list_id   2500 non-null   int64
#  4   aqs_date  2500 non-null   object
#  5   source    2500 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 117.3+ KB

# %%
# Quantidade de dados salvos
print(f'{len(df_1)} dados salvos')
# Out:
# 2500 dados salvos

# %%
# Quantidade de dados duplicados
#dup_itens = df_1.duplicated(['list_id', 'aqs_date'])
dup_itens = df_1.duplicated(['list_id'])
print(f'{dup_itens.sum()} dados duplicados')
display(df_1[dup_itens].head())
# Out:
# 0 dados duplicados
# Empty DataFrame
# Columns: [link, title, query, list_id, aqs_date, source]
# Index: []

# %%
# Deletando dados duplicados, se aplicavel
df_1.drop_duplicates(subset=['list_id', 'aqs_date'], keep="last", inplace=True)

# Quandidade de dados depois do drop
print(f'{len(df_1)} dados restante depois do drop')
# Out:
# 2500 dados restante depois do drop

# %% [markdown]
# # Salvando a pagina de cada anuncio

# %%
try:
    now = datetime.now().strftime('%Y-%m-%d') # Data de hoje
    os.mkdir(f'./02_raw_data_olx_itens/{now}') # Criando um diretorio com o dia de hoje
except:
    pass

# %%
# Looping para salvar as paginas de cada anuncio


links_list = df_1['link']

i = 1
for link in tqdm.tqdm_notebook(links_list):
    url_ = link
    print(f'Item {i}:\n{url_}')
    
    response = rq.get(url_, headers=headers)
    
    link_name = re.search('(\d+)(?!.*\d)', link).group() # Captura o código de cada anuncio

    with open("./02_raw_data_olx_itens/{}/item_cod_{}.html".format(now, link_name), 'w+', encoding='utf-8') as output:
        output.write(response.text)
    time.sleep(1)
    i  += 1
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Item 1:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/aluga-se-apto-no-centro-sp-955129983
# Item 2:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/excelente-apartamento-aclimacao-todo-reformado-955121409
# Item 3:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-residencial-para-locacao-3-dts-vaga-de-garagem-r-2900-00-945892190
# Item 4:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/aluga-se-kitnet-na-regiao-do-bras-sem-analise-de-credito-929533029
# Item 5:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-para-aluguel-possui-160-metros-quadrados-com-3-quartos-em-santa-cecilia-sao-935621122
# Item 6:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/kitnet-confortavel-e-aconchegante-prox-metro-944239390
# Item 7:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/amplo-apartamento-ao-lado-do-parque-da-aclimacao-e-avenida-lins-de-vasconcelos-59-m-uteis-922070493
# Item 8:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-para-aluguel-tem-22-metros-quadrados-com-1-quarto-em-vila-california-sao-pau-931690049
# Item 9:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-para-aluguel-possui-40-metros-quadrados-com-1-quarto-em-consolacao-950238918
# Item 10:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-para-aluguel-com-45-metros-quadrados-com-1-quarto-em-aclimacao-sao-paulo-s-937909142
# Item 11:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis

# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-para-locacao-no-centro-950600512
# Item 2477:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/seguro-fianca-gratuito-studio-de-23-m-com-sacada-950600515
# Item 2478:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-23-m-com-sacada-950600516
# Item 2479:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600518
# Item 2480:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600521
# Item 2481:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-24-95-m-com-sacada-950600523
# Item 2482:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-bem-localizado-disponivel-para-locacao-na-consolacao-950600525
# Item 2483:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-bem-localizado-disponivel-para-locacao-na-consolacao-950600527
# Item 2484:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/excelente-studio-de-22-m-com-sacada-na-se-para-locacao-950600536
# Item 2485:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-bem-localizado-disponivel-para-locacao-na-consolacao-950600537
# Item 2486:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600538
# Item 2487:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/excelente-studio-de-22-81-m-com-sacada-na-se-para-locacao-950600539
# Item 2488:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-perto-da-av-paulista-para-locacao-com-sacada-e-1-vaga-950600540
# Item 2489:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-centro-de-sao-paulo-950600182
# Item 2490:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-com-12-m-campos-eliseos-950600198
# Item 2491:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-23-m-com-sacada-950600216
# Item 2492:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600221
# Item 2493:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-de-44-m-com-sacada-950600236
# Item 2494:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-24-95-m-com-sacada-950600288
# Item 2495:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/apartamento-de-44-m-com-sacada-950600333
# Item 2496:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/otimo-apartamento-de-42-m-com-sacada-para-locacao-950600339
# Item 2497:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-23-m-com-sacada-950600342
# Item 2498:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600351
# Item 2499:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-23-m-com-sacada-950600359
# Item 2500:
# https://sp.olx.com.br/sao-paulo-e-regiao/imoveis/studio-de-22-m-com-sacada-950600365

# %% [markdown]
# # Coletando os dados dos links de cada item

# %% [markdown]
# ## Scratch

# %% [raw]
# # Criando um json para capturar as informacoes em um dataframe
# with open(f"./parsed_itens_info/parsed_itens_info_{now}.json", 'w+', encoding='utf-8') as output:
#     # Para cada pagina salva (anuncios), coletar as informacoes brutas
#     for item in tqdm.tqdm_notebook(sorted(glob.glob(f"./01_raw_data_olx_itens/{now}/item_cod*"))):
#         try:
#             with open(item, 'r+', encoding='utf-8') as html:
#                 page_html = html.read()
#
#                 parsed = bs4.BeautifulSoup(page_html, 'html.parser')
#                 item_info = parsed.find_all(string=re.compile("window.dataLayer"))
#
#         except Exception as e:
#             print(e)
#             print(item)

# %% [raw]
# # Informacoes brutas
# item_info

# %% [raw]
# # Fazendo a selecao das informacoes brutas
# data = dict()
# for i in item_info[0].split(',"'):
#     key = i.split(':')[0].replace('"', '').strip()
#     value = i.split(':')[1].replace('"', '').replace('}', '').replace('{', '').replace(']', '').strip()
#     key = unidecode(key).lower()
#     value = unidecode(value).lower()
#
#     data[key] = value
#     data['aqs_date'] = now
#
#     print(f'{key}: {value}')
#
# # Adicionando no json os dados de cada item
# with open(f"./parsed_itens_info/parsed_itens_info_{now}.json", "a+") as output:
#     output.write("{}\n".format(json.dumps(data)))
# print('')
# print(data)

# %% [raw]
# # Dataframe com os dados dos itens
# df_2 = pd.read_json(f'./parsed_itens_info/parsed_itens_info_{now}.json', lines=True)
# df_2.drop_duplicates(inplace=True)

# %% [raw]
# # Todas as colunas brutas
# df_2.columns

# %% [markdown]
# ## Full

# %%
with open(f"./02_parsed_itens_info/parsed_itens_info_{now}.json", 'w+', encoding='utf-8') as output:
    for item in tqdm.tqdm_notebook(sorted(glob.glob(f"./02_raw_data_olx_itens/{now}/item_cod*"))):
        try:
            with open(item, 'r+', encoding='utf-8') as html:
                page_html = html.read()
            
                parsed = bs4.BeautifulSoup(page_html, 'html.parser')
                item_info = parsed.find_all(string=re.compile("window.dataLayer"))
                
                desc = parsed.find_all("span", {"class": "sc-1sj3nln-1 eOSweo sc-ifAKCX cmFKIN"})
                desc = str(desc[0].text)
                
        except Exception as e: 
            print(e)
            print(item)
            continue
            
        data = dict()
        for i in item_info[0].split(',"'):
            try:
                key = i.split(':')[0].replace('"', '').strip()
                value = i.split(':')[1].replace('"', '').replace('}', '').replace('{', '').replace(']', '').strip()
                key = unidecode(key).lower()
                value = unidecode(value).lower()
            
                data[key] = value
                
            except:
                continue
                
        data['aqs_date'] = now
        data['desc'] = desc
        
        with open(f"./02_parsed_itens_info/parsed_itens_info_{now}.json", "a+") as output:
            output.write("{}\n".format(json.dumps(data)))
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_906585381.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_914787379.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_922161605.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_922161760.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_922986992.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_922987041.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_926514114.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_926928016.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_931584289.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_935421546.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_935884055.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_937909157.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_938164382.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_939091455.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_940282788.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_940467961.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_940504659.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_941831817.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944003411.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944244837.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944285283.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944660637.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944709953.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_944722362.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_945798033.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_946429860.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_946430367.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_947373066.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_949867120.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950582419.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600451.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600452.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600454.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600461.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600472.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600488.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600490.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600512.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600515.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600554.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600555.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600558.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600567.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600599.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600605.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950600767.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950665433.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950665572.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950665602.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950665648.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950678099.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950683889.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950688737.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950688755.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_950709703.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_951041575.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_952980515.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_952980586.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_952997365.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_952997876.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953011187.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953027290.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953027380.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953034520.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953036956.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953039244.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953039256.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953039501.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953041658.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953051419.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953067643.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953067767.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953094814.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953095618.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953095715.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953095728.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953095787.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953095907.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953096181.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953096202.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953104361.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953104480.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953111049.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953149127.html
# list index out of range
# ./02_raw_data_olx_itens/2021-11-10\item_cod_953149323.html

# %%
df_2 = pd.read_json(f'./02_parsed_itens_info/parsed_itens_info_{now}.json', lines=True)
df_2.head()
# Out:
#   window.datalayer = [{page  detail  state_id    list_id  parent_category_id  \
# 0                  pagetype  addate        11  625553376                1000
# 1                  pagetype  addate        11  639983350                1000
# 2                  pagetype  addate        11  642515452                1000
# 3                  pagetype  addate        11  668386502                1000
# 4                  pagetype  addate        11  671376395                1000
#
#    category_id  city_id  zipcode price olxpay  ... userid   pagetype  \
# 0         1020     3370  1502001  2700         ...   null  ad_detail
# 1         1020     3370  1502001  1500         ...   null  ad_detail
# 2         1020     3370  1306001  3300         ...   null  ad_detail
# 3         1020     3370  1502001  1500         ...   null  ad_detail
# 4         1020     3370  1150000  4900         ...   null  ad_detail
#
#    abtestingenable     listid      site source    aqs_date  \
# 0                1  625553376  ismobile    web  2021-11-10
# 1                1  639983350  ismobile    web  2021-11-10
# 2                1  642515452  ismobile    web  2021-11-10
# 3                1  668386502  ismobile    web  2021-11-10
# 4                1  671376395  ismobile    web  2021-11-10
#
#                                                 desc  condominio   size
# 0  Apto c/ 2 dormitórios, sendo 1 dorm c/guarda-r...         NaN    NaN
# 1  kitnet na Glicério Valor a partir de R$ 1.500,...         NaN    NaN
# 2  Código do anúncio: 113422\nPé direito alto, ja...      r$ 708  110.0
# 3  Kit com sala grande, banheiro, sem divisórias,...         NaN    NaN
# 4  Código do anúncio: SC4364\nCobertura na Santa ...    r$ 1.900  330.0
#
# [5 rows x 48 columns]

# %% [markdown]
# # Juntando os dataframes (links com os itens)

# %%
df_full = pd.merge(df_1, df_2, how = 'left', on = ['list_id', 'aqs_date']) # df_1: dataframe com os dados com os links(aba), df_2: informacoes dentro de cada link
df_full.head()
# Out:
#                                                 link  \
# 0  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 1  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 2  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 3  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
# 4  https://sp.olx.com.br/sao-paulo-e-regiao/imove...
#
#                                                title             query  \
# 0                         Aluga-se Apto no Centro SP  filtro_centro_sp
# 1  excelente apartamento aclimacao , todo reformado,  filtro_centro_sp
# 2  Apartamento Residencial para locação, 3 Dts, V...  filtro_centro_sp
# 3  Aluga-se kitnet na região do Brás ( sem analis...  filtro_centro_sp
# 4  Apartamento para aluguel possui 160 metros qua...  filtro_centro_sp
#
#      list_id    aqs_date source_x window.datalayer = [{page  detail  state_id  \
# 0  955129983  2021-11-10      olx                  pagetype  addate      11.0
# 1  955121409  2021-11-10      olx                  pagetype  addate      11.0
# 2  945892190  2021-11-10      olx                  pagetype  addate      11.0
# 3  929533029  2021-11-10      olx                  pagetype  addate      11.0
# 4  935621122  2021-11-10      olx                  pagetype  addate      11.0
#
#    parent_category_id  ...  session  userid   pagetype abtestingenable  \
# 0              1000.0  ...     user    null  ad_detail             1.0
# 1              1000.0  ...     user    null  ad_detail             1.0
# 2              1000.0  ...     user    null  ad_detail             1.0
# 3              1000.0  ...     user    null  ad_detail             1.0
# 4              1000.0  ...     user    null  ad_detail             1.0
#
#         listid      site source_y  \
# 0  955129983.0  ismobile      web
# 1  955121409.0  ismobile      web
# 2  945892190.0  ismobile      web
# 3  929533029.0  ismobile      web
# 4  935621122.0  ismobile      web
#
#                                                 desc condominio   size
# 0  Apto super arejado e iluminado pois fica no 12...     r$ 560   57.0
# 1  amplo apartamento todo reformado, 01 vaga, bem...     r$ 250   80.0
# 2  Código do anúncio: 9936\nApartamento Residenci...     r$ 650  104.0
# 3  ALUGA-SE KITNET'S SEM ANÁLISE DE CRÉDITO E 2 M...        NaN   27.0
# 4  Código do anúncio: SH-AL-HEL\n\nO apartamento ...   r$ 1.700  160.0
#
# [5 rows x 52 columns]

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   link                        2500 non-null   object
#  1   title                       2500 non-null   object
#  2   query                       2500 non-null   object
#  3   list_id                     2500 non-null   int64
#  4   aqs_date                    2500 non-null   object
#  5   source_x                    2500 non-null   object
#  6   window.datalayer = [{page   2415 non-null   object
#  7   detail                      2415 non-null   object
#  8   state_id                    2415 non-null   float64
#  9   parent_category_id          2415 non-null   float64
#  10  category_id                 2415 non-null   float64
#  11  city_id                     2415 non-null   float64
#  12  zipcode                     2415 non-null   float64
#  13  price                       2415 non-null   object
#  14  olxpay                      2415 non-null   object
#  15  olxdelivery                 2415 non-null   object
#  16  vehiclereport               2415 non-null   object
#  17  tagssize                    2415 non-null   float64
#  18  addetail                    2415 non-null   object
#  19  sellername                  2415 non-null   object
#  20  addate                      2415 non-null   object
#  21  maincategory                2415 non-null   object
#  22  subcategory                 2415 non-null   object
#  23  maincategoryid              2415 non-null   float64
#  24  subcategoryid               2415 non-null   float64
#  25  state                       2415 non-null   object
#  26  ddd                         2415 non-null   float64
#  27  brand                       2415 non-null   object
#  28  model                       2415 non-null   object
#  29  version                     2415 non-null   object
#  30  gearbox                     2415 non-null   object
#  31  subject                     2415 non-null   object
#  32  region                      2415 non-null   object
#  33  category                    2415 non-null   object
#  34  real_estate_type            2415 non-null   object
#  35  iptu                        1896 non-null   object
#  36  rooms                       2415 non-null   object
#  37  bathrooms                   2376 non-null   object
#  38  garage_spaces               2041 non-null   object
#  39  apartment_features          1476 non-null   object
#  40  apartment_complex_features  1362 non-null   object
#  41  pictures                    2415 non-null   float64
#  42  session                     2415 non-null   object
#  43  userid                      2415 non-null   object
#  44  pagetype                    2415 non-null   object
#  45  abtestingenable             2415 non-null   float64
#  46  listid                      2415 non-null   float64
#  47  site                        2415 non-null   object
#  48  source_y                    2415 non-null   object
#  49  desc                        2415 non-null   object
#  50  condominio                  2256 non-null   object
#  51  size                        2406 non-null   float64
# dtypes: float64(13), int64(1), object(38)
# memory usage: 1.0+ MB

# %%
# Quantidade de dados salvos
print(f'{len(df_full)} dados salvos')
# Out:
# 2500 dados salvos

# %%
# Quantidade de dados duplicados
dup_itens = df_full.duplicated(['list_id', 'aqs_date', 'link'])
print(f'{dup_itens.sum()} dados duplicados')
display(df_full[dup_itens].head())
# Out:
# 0 dados duplicados
# Empty DataFrame
# Columns: [link, title, query, list_id, aqs_date, source_x, window.datalayer = [{page, detail, state_id, parent_category_id, category_id, city_id, zipcode, price, olxpay, olxdelivery, vehiclereport, tagssize, addetail, sellername, addate, maincategory, subcategory, maincategoryid, subcategoryid, state, ddd, brand, model, version, gearbox, subject, region, category, real_estate_type, iptu, rooms, bathrooms, garage_spaces, apartment_features, apartment_complex_features, pictures, session, userid, pagetype, abtestingenable, listid, site, source_y, desc, condominio, size]
# Index: []
#
# [0 rows x 52 columns]

# %%
# Deletando dados duplicados, se aplicavel
df_full.drop_duplicates(subset=['list_id', 'aqs_date'], keep="first", inplace=True)

# Quandidade de dados depois do drop
print(f'{len(df_full)} dados restante depois do drop')
# Out:
# 2500 dados restante depois do drop

# %%
df_full.shape
# Out:
# (2500, 52)

# %%
now_2 = datetime.now().strftime("%m-%d-%Y_%H%M%S") # Data e horario
df_full.to_csv(f'./data/01_raw_df/raw_df_{now_2}.csv', sep='|',  index=False) # Cria o dataframe
